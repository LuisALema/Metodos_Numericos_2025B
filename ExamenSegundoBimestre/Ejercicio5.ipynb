271.179, 118.383, 185.304, 289.344, 288.652, 272.186, 142.073, 306.702,
300.977, 260.814, 209.756, 272.194, 293.648, 250.622, 293.963, 297.446,
287.544, 279.58, 285.889, 296.984, 209.147, 263.333, 272.813, 226.847,
223.68, 245.787, 255.12, 300.035, 260.956, 236.865, 223.838, 299.782,
305.318, 248.435, 296.226, 308.121, 272.847, 266.499, 296.48, 246.398,
98.855, 131.82, 252.325, 302.85, 245.391, 160.715, 211.185, 199.612,
233.251, 278.807, 253.259, 297.536, 301.492, 279.75, 301.574, 301.841,
205.542, 263.34, 145.435, 244.165, 302.421, 272.136, 129.284, 248.809,
285.51, 228.711, 164.503, 173.008, 295.952, 302.948, 303.511, 256.152,
237.062, 292.451, 218.657, 298.79, 300.864, 301.543, 305.138, 174.301,
293.614, 256.253, 271.269, 288.815, 288.01, 262.334, 221.177, 301.852,
298.586, 239.195, 196.542, 209.745, 202.039, 180.44, 293.986, 218.757,
218.385, 235.877, 297.12, 203.075, 153.717, 250.583, 290.423, 215.36,
213.679, 296.216, 307.861, 275.744, 283.676, 151.994, 150.448, 286.426,
137.853, 185.381, 254.25, 297.928, 225.713, 298.374, 264.854, 108.138,
263.082, 302.165, 224.618, 191.864, 298.192, 301.635, 309.26, 300.233,
301.76, 226.909, 291.985, 307.196, 188.047, 140.068, 174.619, 192.334,
167.401, 234.86, 301.082, 281.013, 304.052, 102.537, 249.41, 266.892,
249.634, 116.364, 299.557, 276.686, 291.0, 294.343, 121.272, 291.969,
270.013, 166.695, 282.435, 282.807, 250.263, 271.703, 241.859, 125.348,
196.418, 123.603, 284.002, 302.162, 257.683, 265.16, 232.684, 159.483
]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Construir gradientes para polinomio de grado 4
def der_parcial_k(xs, ys, k):
    """Derivada parcial respecto al parámetro k para ajuste polinómico de grado 4"""
    n = 5
    c = []
    for i in range(n):
        c_i = sum(x**(i+k) for x in xs)
        c.append(c_i)
    c_ind = sum(y * (x**k) for x, y in zip(xs, ys))
    return (*c, c_ind)

gradiente = [
    lambda xs, ys: der_parcial_k(xs, ys, 0),
    lambda xs, ys: der_parcial_k(xs, ys, 1),
    lambda xs, ys: der_parcial_k(xs, ys, 2),
    lambda xs, ys: der_parcial_k(xs, ys, 3),
    lambda xs, ys: der_parcial_k(xs, ys, 4),
]

from src import ajustar_min_cuadrados

# Ajuste por mínimos cuadrados usando las derivadas parciales para grado 4
parametros = ajustar_min_cuadrados(xs, ys, gradiente=gradiente)

# Crear valores para graficar el polinomio ajustado
x_linea = np.linspace(min(xs), max(xs), 100)
y_linea = sum(parametros[i] * x_linea**i for i in range(5))

def modelo(x):
    return sum(parametros[i] * x**i for i in range(5))

# Graficar los datos y el polinomio ajustado
plt.scatter(xs, ys, label='Datos')
plt.plot(x_linea, y_linea, color='red', label='Polinomio ajustado')
plt.xlabel('Valores de X')
plt.ylabel('Valores de Y')
plt.title('Ajuste polinómico de grado 4 por mínimos cuadrados')
plt.legend()
plt.show()

# Calcular el error relativo promedio y el máximo error relativo
errores_relativos = [abs(ys[j] - modelo(xs[j])) / abs(ys[j]) for j in range(len(xs))]
error_promedio = np.mean(errores_relativos)
error_maximo = np.max(errores_relativos)

# Imprimir el polinomio ajustado y los errores
print(f'Polinomio ajustado: y = {parametros[4]:.4f} x^4 + {parametros[3]:.4f} x^3 + {parametros[2]:.4f} x^2 + {parametros[1]:.4f} x + {parametros[0]:.4f}')
print(f'Error relativo promedio: {error_promedio}')
print(f'Máximo error relativo: {error_maximo}')
# Out:
# [01-30 12:59:15][INFO] Se ajustarán 5 parámetros.
# [01-30 12:59:15][INFO]
# [[ 2.00000000e+02 -4.00000000e+03  8.67333367e+04 -2.00400020e+06
#    4.85680353e+07  4.99224600e+04]
#  [ 0.00000000e+00  6.73333670e+03 -2.69333468e+05  8.48803125e+06
#   -2.48108951e+08  3.40789355e+04]
#  [ 0.00000000e+00 -2.69333468e+05  1.09546768e+07 -3.50401536e+08
#    1.03752669e+10 -1.63563221e+06]
#  [ 0.00000000e+00  8.48803125e+06 -3.50401536e+08  1.13575217e+10
#   -3.40196894e+11  5.92984086e+07]
#  [ 0.00000000e+00 -2.48108951e+08  1.03752669e+10 -3.40196894e+11
#    1.02937507e+13 -1.93250598e+09]]
# [01-30 12:59:15][INFO]
# [[ 2.00000000e+02 -4.00000000e+03  8.67333367e+04 -2.00400020e+06
#    4.85680353e+07  4.99224600e+04]
#  [ 0.00000000e+00  6.73333670e+03 -2.69333468e+05  8.48803125e+06
#   -2.48108951e+08  3.40789355e+04]
#  [ 0.00000000e+00  0.00000000e+00  1.81338098e+05 -1.08802859e+07
#    4.50908872e+08 -2.72474796e+05]
# ...

# %%
from src import ajustar_min_cuadrados
import matplotlib.pyplot as plt
import numpy as np

# Ajuste polinómico de grado 4 usando numpy
grado = 4
coeficientes = np.polyfit(xs, ys, grado)

# Crear valores para graficar el polinomio ajustado
x_linea = np.linspace(min(xs), max(xs), 100)
y_linea = np.polyval(coeficientes, x_linea)

def modelo(x):
    return np.polyval(coeficientes, x)

# Graficar los datos y el polinomio ajustado
plt.scatter(xs, ys, label='Datos')
plt.plot(x_linea, y_linea, color='red', label='Polinomio ajustado')
plt.xlabel('Valores de X')
plt.ylabel('Valores de Y')
plt.title('Ajuste polinómico de grado 4')
plt.legend()
plt.show()

# Calcular el error relativo promedio y el máximo error relativo
errores_relativos = [abs(ys[j] - modelo(xs[j])) / abs(ys[j]) for j in range(len(xs))]
error_promedio = np.mean(errores_relativos)
error_maximo = np.max(errores_relativos)

# Imprimir el polinomio ajustado y los errores en el formato solicitado
print(f"Polinomio ajustado: y = {coeficientes[0]:.4f} x^4 + {coeficientes[1]:.4f} x^3 + {coeficientes[2]:.4f} x^2 + {coeficientes[3]:.4f} x + {coeficientes[4]:.4f}")
print(f"Error relativo promedio: {error_promedio}")
print(f"Máximo error relativo: {error_maximo}")
# Out:
# Polinomio ajustado: y = -0.0003 x^4 + -0.0273 x^3 + -2.3578 x^2 + -66.4323 x + -253.6796
# Error relativo promedio: 0.008959234167439677
# Máximo error relativo: 0.02776798005421045
