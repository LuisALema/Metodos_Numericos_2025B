# %% [markdown]
# # **Escuela Politécnica Nacional**
# ## **[Actividad extracurricular 05] Tipografía matemática**
# ### **Nombre:** Luis Alexander Lema Delgado
# ### **Fecha:** 02/11/2025
# ### **Curso:** GR1CC

# %% [markdown]
# # Actividad: Redacción de Expresiones Matemáticas
#
# ## Objetivo
# El objetivo de esta actividad es que cada estudiante alcance proficiencia en la **redacción de expresiones matemáticas**, tanto en Word como en LaTeX.

# %% [markdown]
# ## Actividades
#
# 1. **Investigar** sobre los **atajos de teclado** para ingresar ecuaciones matemáticas en:
#    - Microsoft Word
#    - LaTeX
#
# 2. **Realizar una tabla** incluyendo al menos **30 símbolos matemáticos**, indicando:
#    - Símbolo
#    - Atajo en Word
#    - Comando en LaTeX

# %% [markdown]
# ## Ejemplo de Tabla de Símbolos
#
# | Símbolo | Atajo en Word | Comando LaTeX |
# |---------|---------------|---------------|
# | +       | +             | +             |
# | -       | -             | -             |
# | ×       | Alt+0215      | \times        |
# | ÷       | Alt+0247      | \div          |
# | =       | =             | =             |
# | ≠       | Alt+8800      | \neq          |
# | <       | <             | <             |
# | >       | >             | >             |
# | ≤       | Alt+243       | \leq          |
# | ≥       | Alt+242       | \geq          |
# | ±       | Alt+0177      | \pm           |
# | √       | Alt+251       | \sqrt{}       |
# | ∛       | Alt+8731      | \sqrt[3]{}    |
# | ∑       | Alt+228       | \sum          |
# | ∏       | Alt+213       | \prod         |
# | ∫       | Alt+8747      | \int          |
# | ∂       | Alt+8706      | \partial      |
# | ∞       | Alt+236       | \infty        |
# | ∇       | Alt+8711      | \nabla       |
# | ∈       | Alt+8712      | \in          |
# | ∉       | Alt+8713      | \notin        |
# | ∩       | Alt+8745      | \cap          |
# | ∪       | Alt+8746      | \cup          |
# | ⊂       | Alt+8834      | \subset       |
# | ⊆       | Alt+8838      | \subseteq     |
# | ⊄       | Alt+8840      | \nsubseteq    |
# | ∧       | Alt+8743      | \wedge        |
# | ∨       | Alt+8744      | \vee          |
# | ⇒       | Alt+8658      | \Rightarrow   |
# | ⇔       | Alt+8660      | \Leftrightarrow |

# %% [markdown]
# > Esta tabla es un ejemplo inicial, se recomienda completarla hasta cubrir **al menos 30 símbolos** y agregar cualquier símbolo adicional que sea relevante para tus ejercicios de matemáticas.
